# %%
import yfinance as yf

# %%
import os
os.system("export apikey='guest:guest'")
# Out:
# 0

# %%
import tradingeconomics as te
te.login()
# Out:
# 'Logged with guest'

# %%
import tradingeconomics as te 
te.login() 
data = te.getHistoricalData(country = 'Russia', indicator = 'Interest Rate', initDate = '2022-01-01') 
print(data)
# Out:
# HTTP Error 403: No Access to this feature.
# None

# %%
import requests
api_key = 'YOUR_API_KEY'
url = f'https://api.tradingeconomics.com/historical/country/Russia/indicator/Interest%20Rate?c=guest:guest'
data = requests.get(url).json()
print(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/miniconda3/envs/python/lib/python3.12/site-packages/requests/models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/miniconda3/envs/python/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...
